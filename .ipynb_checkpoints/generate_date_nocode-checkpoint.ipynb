# %%
import json
import os
import sys
import io
import psutil
# no code

def clear():    
    os.system('clear')


# class ChatBot:
#     def __init__(self, system=""):
#         self.system = system
#         self.messages = []
#         if self.system:
#             self.messages.append({"role": "system", "content": system})
#
#     def __call__(self, message):
#         self.messages = []
#         self.messages.append({"role": "user", "content": message})
#         result = self.execute()
#         self.messages.append({"role": "assistant", "content": result})
#         # print(self.messages)
#         return result
#
#     def execute(self):
#         completion = openai.ChatCompletion.create(model="gpt-3.5-turbo", messages=self.messages)
#         # Uncomment this to print out token usage each time, e.g.
#         # {"completion_tokens": 86, "prompt_tokens": 26, "total_tokens": 112}
#         # print(completion.usage)
#         return completion.choices[0].message.content
#
#
# openai.api_key = "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"
# verifier = ChatBot()
errors = 0
banned_vars = {'ops', 'memory_leak', 'stdouts', 'fnruinr', 'is_str', 'is_loop', 'data', 'splitted', 'new_res', 'questions',
               'seen', 'this', 'time', 'line_idx', 'start_idx', "statement_file", "code_statements", "code_statement",
               'end_idx' 'psutil', 'words', 'prev_indent', 'multiple_reses', 'output_lines', 'curr_output',
               'output_line', 'jj', 'string', 'banned_vars', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open',
               'openai', 'json', 'os', 'clear', 'to_prompt', 'ChatBot', 'verifier', 'errors', 'sys', 'io', 'debug',
               'indent', 'lines', 'curr_code', 'noprint_code', 'vars', 'var_map', 'vars_list', 'vars_it', 'skip', 'res',
               'code_line', 'it', 'variables', 'variable', 'var', 'old_stdout', 'buffer', 'whatWasPrinted', 'print_res',
               'new_code', 'ans', 'output', 'outfile', 'potential_var', 'found'}

words = ["cupboard", "dog", "cat", "funny", "pillow", "coffee maker", "bed", "spoon", "blanket", "knife", "stove",
         "sink", "washing machine", "pot", "dish", "fridge", "sofa", "stool", "cup", "fork", "glass", "attractive",
         "bald", "beautiful", "chubby", "clean", "dazzling", "drab", "elegant", "fancy",
         "fit", "flabby", "glamorous", "gorgeous", "handsome", "long", "magnificent", "muscular", "plain", "plump",
         "quaint", "scruffy", "shapely", "short", "skinny", "stocky", "ugly", "unkempt", "unsightly",
         "agreeable", "ambitious", "brave", "calm", "delightful", "eager", "faithful", "gentle",
         "happy", "jolly", "kind", "lively", "nice", "obedient", "polite", "proud", "silly", "thankful", "victorious",
         "witty", "wonderful", "zealous", "angry", "bewildered", "clumsy", "defeated", "embarrassed", "fierce",
         "grumpy", "helpless", "itchy", "jealous", "lazy", "mysterious", "nervous", "obnoxious",
         "panicky", "pitiful", "scary", "thoughtless", "uptight", "worried", "broad", "chubby", "crooked",
         "curved", "deep", "flat", "high", "hollow", "low", "narrow", "refined", "round", "shallow", "skinny", "square",
         "steep", "straight", "wide", "big", "colossal", "fat", "gigantic", "great", "huge",
         "immense", "large", "little", "mammoth", "massive", "microscopic", "miniature", "petite", "puny", "scrawny",
         "short", "small", "tall", "teeny", "tiny"]
debug = []
indent = 0
prev_indent = 0
is_loop = False
# statement_file = open("/home/mcwave/data/python/statements.json")
# code_statements = json.load(statement_file)
# seen = {"temp"}
for fnruinr in range(1000000):
    try:
        code_statement = verifier("Generate a "+random.choice(words)+" Python 3 code that defines no functions or classes. Use complex operations such as sorting ")
        # code_statement = code_statements[fnruinr]["statement"]
        code_statement = code_statement.replace("<", "")
        code_statement = code_statement.replace("|", "")
        code_statement = code_statement.replace("    ", "")
        # with open("/home/mcwave/data/python/statements.json", "a") as outfile:
        #     json.dump({"statement":statement},outfile)
        #     outfile.write("\n")
        start_idx = 0
        end_idx = len(code_statement) - 1
        for j in range(len(code_statement)):
            if j < len(code_statement) - 3 and (code_statement[j:j + 3] == "```" or code_statement[j:j + 3] == "'''" or code_statement[j:j + 3] == '''"""'''):
                if start_idx:
                    end_idx = j
                    break
                if j < len(code_statement) - 9 and code_statement[j + 3:j + 9] == "python":
                    start_idx = j + 9
                else:
                    start_idx = j + 3
        code_statement = code_statement[start_idx:end_idx + 1]
        code_statement = code_statement.replace("    ", "")
        code_statement = code_statement.replace("`", "")
        if "os." in code_statement or "while" in code_statement or "def" in code_statement or "input" in code_statement or "random" in code_statement or "turtle" in code_statement or "time" in code_statement or "PIL" in code_statement or "list" in code_statement or "set" in code_statement:
            continue
        lines = code_statement.split("\n")
        lines.append("\n")
        curr_code = ""
        noprint_code = ""
        vars = {"temp"}
        var_map = {"temp": ""}
        stdouts = {"temp"}
        vars_list = []
        vars_it = {"temp"}
        skip = False
        res = ""
        line_idx = 0
        memory_leak = False
        for code_line in lines:
            if len(code_line) < 3 or code_line[0] == "#":
                continue
            code_line = code_line.split("#")[0]
            if len(res) == 0:
                res += "variables: "
            elif res[-11:] != "variables: ":
                res += ", variables: "
            splitted = code_line.replace(",", " ").split(" ")
            if "os" in splitted:
                break
            if len(splitted) > 1 and code_line.split()[0] in ["for"]:
                for potential_var in splitted[1:-1]:
                    if potential_var not in ["in", ""] and potential_var not in vars:
                        vars_list.append(potential_var)
                        vars_it.add(potential_var)
                        vars.add(potential_var)
            if indent and ("elif" in code_line or "else:" in code_line):
                indent -= 1
            if is_loop:
                found = False
                for var in vars_it:
                    for jj in range(len(code_line) - len(var)):
                        if code_line[jj:jj + len(var)] == var and (jj == len(code_line) - len(var) - 1 or (
                                code_line[jj + len(var)] not in "qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM_")):
                            found = True
                            break
                    if found:
                        break
                if found or "for" in lines[line_idx - 1] or "if" in lines[line_idx - 1] or "else:" in lines[line_idx - 1] or "elif" in lines[line_idx - 1]:
                    pass
                else:
                    indent = max(indent - 1, 0)
            if code_line.split(" ")[0] in ["elif", "else:"]:
                indent = max(indent - 1, prev_indent)
            if indent:
                curr_code += "    " * indent
                noprint_code += "    " * indent
            curr_code += code_line + "\n"
            if "print" not in code_line:
                noprint_code += code_line + "\n"
            else:
                noprint_code += "pass" + "\n"
            try:
                exec(noprint_code)
                # if psutil.virtual_memory()[2] > 20:
                #     break
            except:
                pass
            variables = list(locals())
            splitted = set(code_statement.replace("\n", " ").replace("*", " ").replace("/", " ").replace("+", " ").replace("-", " ").replace("=", " ").split(" "))
            for variable in variables:
                if variable[0] != "_" and variable not in vars and variable not in banned_vars and variable in splitted:
                    vars.add(variable)
                    vars_list.append(variable)
            if code_line.split(" ")[0] in ["for", "if"]:
                prev_indent = indent
            if code_line.split(" ")[0] == "for":
                is_loop = True
            if code_line.split(" ")[0] in ["for", "if", "elif", "else:"]:
                indent += 1
            if len(vars_list):
                try:
                    ans = "< "
                    for var in vars_list:
                        if not is_loop and var in vars_it:
                            continue
                        old_stdout = sys.stdout
                        sys.stdout = buffer = io.StringIO()
                        new_code = noprint_code + "\n"
                        if indent:
                            new_code += "    " * indent
                        new_code += "print(" + var + ")\n"
                        if indent:
                            new_code += "    " * indent
                        new_code += '''print("SEP")'''
                        exec(new_code)
                        # if psutil.virtual_memory()[2] > 20:
                        #     memory_leak = True
                        #     break
                        sys.stdout = old_stdout
                        whatWasPrinted = buffer.getvalue()
                        clear()
                        if len(whatWasPrinted) > 0:
                            output_lines = whatWasPrinted.split("SEP")
                            final_res = whatWasPrinted.split("\n")
                            while len(output_lines) > 0 and (output_lines[-1] == "" or output_lines[-1] == "\n"):
                                output_lines = output_lines[:-1]
                            while len(final_res) > 0 and (
                                    final_res[-1] == "" or final_res[-1] == "\n" or final_res[-1] == "SEP"):
                                final_res = final_res[:-1]
                            print_res = True
                            if var in var_map and var_map[var] == final_res[-1]:
                                print_res = False
                            curr_output = ""
                            if print_res:
                                if len(output_lines) == 1:
                                    if not (var in var_map and var_map[var] == output_lines[-1].replace("\n", "")):
                                        if type(globals()[var]) == str:
                                            ans += var + " : " + '"' + output_lines[-1] + '"'
                                        else:
                                            ans += var + " : " + output_lines[-1] + ", "
                                    while len(ans) > 1 and ans[-2:] == ", ":
                                        ans = ans[:-2]
                                    curr_output = output_lines[-1]
                                else:
                                    ans += " | "
                                    curr_output = ""
                                    for output_line in output_lines:
                                        if output_line == curr_output or len(output_line) == 0 or output_line == "\n":
                                            continue
                                        if len(output_line.replace(" ", "")) == 0:
                                            ans += var + " : " + "None, "
                                            curr_output = output_line
                                        else:
                                            if type(globals()[var]) == str:
                                                ans += var + " : " + '"' + output_line + '"' + ", "
                                            else:
                                                ans += var + " : " + output_line + ", "
                                            curr_output = output_line
                                    while len(ans) > 1 and ans[-2:] == ", ":
                                        ans = ans[:-2]
                                    ans += " | "
                                    if ans == '<  | | ':
                                        ans = ""
                                var_map[var] = curr_output.replace("\n", "")
                                try:
                                    if int(var_map[var]) >= 1000000:
                                        res += "None"
                                        memory_leak = True
                                        break
                                except:
                                    pass
                    if memory_leak:
                        break
                    ans += " >"
                    ans = ans.replace("\n", "")
                    if ans == "<  >":
                        ans = "None"
                    res += ans + ", "
                except:
                    res += "Error, "
            else:
                res += "None, "
            try:
                old_stdout = sys.stdout
                sys.stdout = buffer = io.StringIO()
                exec(curr_code)
                # if psutil.virtual_memory()[2] > 20:
                #     break
                sys.stdout = old_stdout
                whatWasPrinted = buffer.getvalue()
                clear()
                multiple_reses = len(whatWasPrinted.split("\n")) > 1
                ans = ""
                if multiple_reses:
                    ans += "< "
                    for output in whatWasPrinted.split("\n"):
                        if str(output) not in stdouts:
                            stdouts.add(str(output))
                            if "[" in whatWasPrinted:
                                ans += str(output) + ", "
                            else:
                                is_str = False
                                for it in '''`~!@#$%^&*()-=_+[]{}\|:;"',./<>?qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM''':
                                    if it in output:
                                        is_str = True
                                        break
                                if is_str:
                                    ans += '"' + output + '"' + ", "
                                else:
                                    ans += output + ", "
                    while len(ans) > 1 and ans[-2:] == ", ":
                        ans = ans[:-2]
                    ans += " >"
                if ans == "<  >":
                    ans = "None, "
                if ans != "None, ":
                    res += ans
            except:
                pass
            line_idx += 1
            while len(res) > 1 and res[-2:] == ", ":
                res = res[:-2]
            # if line_idx % 2 == 0 and line_idx > 1:
            #     res += "\ncode: " + code_line.replace("\n", "") + "\n"
        if len(vars_list) != 0:
            with open("/home/mcwave/data/python/tmp.json", "a") as outfile:
                if len(res) < 10000:
                    json.dump({"response": code_statement, "prompt": ""}, outfile)
                    outfile.write("\n")
            for var in vars_list:
                try:
                    new_code = "del " + var
                    exec(new_code)
                except:
                    pass
    except:
        pass
debug = []
